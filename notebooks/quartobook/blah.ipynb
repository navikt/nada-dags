# %% [raw]
# ---
# name: blah
# jupyter: python3
# ---

# %%
#| output: false
import datetime as dt

# %%
print(f'Sist oppdatert: {dt.datetime.now().strftime("%Y-%m-%d %H:%M")}')
# Out:
# Sist oppdatert: 2025-10-13 08:26
